# %%
# !git clone https://github.com/mohit-epic/glf-crP.git
# Out:
# Cloning into 'glf-crP'...
# remote: Enumerating objects: 475, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 475 (delta 22), reused 42 (delta 15), pack-reused 417 (from 1)
# Receiving objects: 100% (475/475), 69.58 MiB | 32.61 MiB/s, done.
# Resolving deltas: 100% (141/141), done.

# %%
cd /kaggle/working/glf-crP/Downloads/Year 4 - project/glff - Copy/GLF-CR/codes
# Out:
# /kaggle/working/glf-crP/Downloads/Year 4 - project/glff - Copy/GLF-CR/codes

# %%
ls
# Out:
# analyze_cloud_coverage.py    generic_train_test.py  test_CR_kaggle.py
# check_data_stats.py          metrics.py             test_CR.py
# checkpoints/                 model_base.py          testCustom_CR.py
# dataloader.py                model_CR_net.py        test_dataloader.py
# FAC/                         net_CR_RDN.py          train_CR_kaggle.py
# feature_detectors.py         replace_data_csv.py    train_CR_net.py
# generate_data_csv.py         submodules.py          train_CR.py
# generate_kaggle_data_csv.py  test_CR_cpu.py

# %%
# !cd /kaggle/working/glf-crP && git pull origin main
# Out:
# From https://github.com/mohit-epic/glf-crP
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python generate_kaggle_data_csv.py
# Out:
# Scanning dataset at: /kaggle/input/sen12ms-cr-winter
# Indexed folders -> S1: 27, S2: 27, S2_cloudy: 27
# Total matched triplets: 18333
# Wrote train/val/test and combined CSVs to /kaggle/working
# train: 12833, val: 2749, test: 2751

# %%
# !python test_CR_kaggle.py
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
# !python train_CR_kaggle.py \
    --batch_sz 2 \
    --num_workers 4 \
    --max_epochs 1 \
    --lr 1e-4 \
    --input_data_folder /kaggle/input/sen12ms-cr-winter \
    --data_list_filepath /kaggle/working/data.csv \
    --save_model_dir /kaggle/working/checkpoints \
    --experiment_name "dual_gpu_training"
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %% [raw]
# import gc
# import torch
#
# # Clear CUDA cache
# torch.cuda.empty_cache()
# gc.collect()
#
# # Check GPU memory
# print("GPU Memory Status:")
# for i in range(torch.cuda.device_count()):
#     print(f"\nGPU {i}: {torch.cuda.get_device_name(i)}")
#     print(f"  Allocated: {torch.cuda.memory_allocated(i) / 1024**3:.2f} GB")
#     print(f"  Reserved: {torch.cuda.memory_reserved(i) / 1024**3:.2f} GB")
#     print(f"  Total: {torch.cuda.get_device_properties(i).total_memory / 1024**3:.2f} GB")
