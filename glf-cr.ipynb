# %%
# !git clone https://github.com/ESWARALLU/glfCRPLUS.git
# Out:
# Cloning into 'glfCRPLUS'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 86 (delta 6), reused 86 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 49.02 MiB | 48.17 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
cd /kaggle/working/glfCRPLUS/codes
# Out:
# /kaggle/working/glfCRPLUS/codes

# %%
ls
# Out:
# analyze_cloud_coverage.py    generic_train_test.py  test_CR_cpu.py
# check_data_stats.py          metrics.py             test_CR_kaggle.py
# checkpoints/                 model_base.py          test_CR.py
# dataloader.py                model_CR_net.py        testCustom_CR.py
# FAC/                         net_CR_RDN.py          test_dataloader.py
# feature_detectors.py         __pycache__/           train_CR_kaggle.py
# generate_data_csv.py         replace_data_csv.py    train_CR_net.py
# generate_kaggle_data_csv.py  submodules.py          train_CR.py

# %%
# !cd /kaggle/working/glfCRPLUS && git pull origin main
# Out:
# From https://github.com/ESWARALLU/glfCRPLUS
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python generate_kaggle_data_csv.py
# Out:
# Scanning dataset at: /kaggle/input/sen12ms-cr-winter
# Indexed folders -> S1: 27, S2: 27, S2_cloudy: 27
# Total matched triplets: 18333
# Wrote train/val/test and combined CSVs to /kaggle/working
# train: 12833, val: 2749, test: 2751

# %%
# !python test_CR_kaggle.py

# %%
# !python train_CR_kaggle.py \
    --batch_sz 10 \
    --num_workers 40 \
    --max_epochs 1 \
    --lr 1e-4 \
    --input_data_folder /kaggle/input/sen12ms-cr-winter \
    --data_list_filepath /kaggle/working/data.csv \
    --save_model_dir /kaggle/working/checkpoints \
    --experiment_name "dual_gpu_training"
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Warning: kernelconv2d_cuda not available. Using standard convolution fallback.
#
# ============================================================
# Training Configuration
# ============================================================
# batch_sz...................... 10
# num_workers................... 40
# load_size..................... 256
# crop_size..................... 128
# input_data_folder............. /kaggle/input/sen12ms-cr-winter
# data_list_filepath............ /kaggle/working/data.csv
# is_use_cloudmask.............. False
# cloud_threshold............... 0.2
# is_test....................... False
# optimizer..................... Adam
# lr............................ 0.0001
# lr_step....................... 5
# lr_start_epoch_decay.......... 5
# max_epochs.................... 1
# save_freq..................... 1
# save_model_dir................ /kaggle/working/checkpoints
# resume_checkpoint............. None
# train_from_scratch............ True
# experiment_name............... dual_gpu_training
# notes.........................
# use_ddp....................... False
# local_rank.................... -1
# ============================================================
#
# GPUs available: 2
# Using DataParallel on 2 GPUs
#
# Training samples: 12833
# Validation samples: 2749
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 40 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model moved to GPU
# ---------- Networks initialized -------------
# [Network] Total number of parameters : 14.827 M
# -----------------------------------------------
# Model wrapped with DataParallel on 2 GPUs
#
# ============================================================
# Starting Training
# ============================================================
#
#
# ============================================================
# Epoch 0/0
# ============================================================
# Training Epoch 0: 100%|█████| 1284/1284 [52:50<00:00,  2.47s/batch, loss=0.0375]
#
# Running validation...
# Validating: 100%|█| 275/275 [03:34<00:00,  1.28batch/s, PSNR=27.09, SSIM=0.8187]
# ✓ Saved checkpoint: /kaggle/working/checkpoints/checkpoint_epoch_0.pth
#
# ============================================================
# Epoch 0 Summary:
#   Train Loss: 0.0375
#   Train PSNR: 25.17 dB
#   Val PSNR:   27.09 dB
#   Val SSIM:   0.8187
#   Best Val PSNR: 27.09 dB (NEW!)
#   Epoch Time: 56.4 minutes
# ============================================================
#
# ============================================================
# Training Complete!
# ============================================================
# Total Time: 0.94 hours
# Best Validation PSNR: 27.09 dB
# Training log saved to: /kaggle/working/checkpoints/logs/dual_gpu_training_log.json
# Best model saved to: /kaggle/working/checkpoints/best_model.pth
# ============================================================

# %%
ls
# Out:
# checkpoint_epoch_0.pth  logs/  model_dataset/

# %%
cd checkpoints
# Out:
# [Errno 2] No such file or directory: 'checkpoints'
# /kaggle/working/checkpoints

# %%
# !cp checkpoint_epoch_0.pth model_dataset/

# %%
# !kaggle datasets create -p model_dataset
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 434, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
