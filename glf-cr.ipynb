# %%
RUN_TRAINING = False

if RUN_TRAINING:
    train()

# %%
# !git clone https://github.com/ESWARALLU/glfCRPLUS.git
# Out:
# Cloning into 'glfCRPLUS'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 92 (delta 0), reused 3 (delta 0), pack-reused 86 (from 1)
# Receiving objects: 100% (92/92), 49.04 MiB | 52.36 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
cd /kaggle/working
# Out:
# /kaggle/working

# %%
ls
# Out:
# glfCRPLUS/  __notebook__.ipynb

# %%
# !cd /kaggle/working/glfCRPLUS && git pull origin main
# Out:
# From https://github.com/ESWARALLU/glfCRPLUS
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !python generate_kaggle_data_csv.py
# Out:
# python3: can't open file '/kaggle/working/generate_kaggle_data_csv.py': [Errno 2] No such file or directory

# %%
# !python test_CR_kaggle.py
# Out:
# python3: can't open file '/kaggle/working/test_CR_kaggle.py': [Errno 2] No such file or directory

# %%
# !python train_CR_kaggle.py \
    --batch_sz 8 \
    --num_workers 8 \
    --max_epochs 1 \
    --lr 1e-4 \
    --input_data_folder /kaggle/input/sen12ms-cr-winter \
    --data_list_filepath /kaggle/working/data.csv \
    --save_model_dir /kaggle/working/checkpoints \
    --experiment_name "dual_gpu_training"
# Out:
# python3: can't open file '/kaggle/working/train_CR_kaggle.py': [Errno 2] No such file or directory

# %%
# !cd /kaggle/working/checkpoints
# Out:
# /bin/bash: line 1: cd: /kaggle/working/checkpoints: No such file or directory

# %%
ls
# Out:
# glfCRPLUS/  __notebook__.ipynb

# %%
# !zip -r checkpoints.zip checkpoints
# Out:
# 	zip warning: name not matched: checkpoints
#
# zip error: Nothing to do! (try: zip -r checkpoints.zip . -i checkpoints)
