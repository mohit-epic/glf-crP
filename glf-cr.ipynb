# %%
# !git clone https://github.com/ESWARALLU/glfCRPLUS.git
# Out:
# fatal: destination path 'glfCRPLUS' already exists and is not an empty directory.

# %%
cd /kaggle/working
# Out:
# /kaggle/working

# %%
ls
# Out:
# checkpoints/  data.csv  glfCRPLUS/  test.csv  train.csv  val.csv

# %%
# !cd /kaggle/working/glfCRPLUS && git pull origin main
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 3), reused 6 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 14.84 KiB | 2.47 MiB/s, done.
# From https://github.com/ESWARALLU/glfCRPLUS
#  * branch            main       -> FETCH_HEAD
#    be50c4c..48dc3f9  main       -> origin/main
# Updating be50c4c..48dc3f9
# Fast-forward
#  KAGGLE_TRAINING_GUIDE.md          | 239 ++++++++++++++++++++++++++++++++++++++
#  codes/kaggle_checkpoint_helper.py | 206 ++++++++++++++++++++++++++++++++
#  codes/train_CR_kaggle.py          |  50 +++++++-
#  3 files changed, 494 insertions(+), 1 deletion(-)
#  create mode 100644 KAGGLE_TRAINING_GUIDE.md
#  create mode 100644 codes/kaggle_checkpoint_helper.py

# %%
# !python generate_kaggle_data_csv.py
# Out:
# Scanning dataset at: /kaggle/input/sen12ms-cr-winter
# Indexed folders -> S1: 27, S2: 27, S2_cloudy: 27
# Total matched triplets: 18333
# Wrote train/val/test and combined CSVs to /kaggle/working
# train: 12833, val: 2749, test: 2751

# %%
# !python test_CR_kaggle.py

# %%
# !python train_CR_kaggle.py \
    --batch_sz 8 \
    --num_workers 8 \
    --max_epochs 1 \
    --lr 1e-4 \
    --input_data_folder /kaggle/input/sen12ms-cr-winter \
    --data_list_filepath /kaggle/working/data.csv \
    --save_model_dir /kaggle/working/checkpoints \
    --experiment_name "dual_gpu_training"
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Warning: kernelconv2d_cuda not available. Using standard convolution fallback.
#
# ============================================================
# Training Configuration
# ============================================================
# batch_sz...................... 8
# num_workers................... 8
# load_size..................... 256
# crop_size..................... 128
# input_data_folder............. /kaggle/input/sen12ms-cr-winter
# data_list_filepath............ /kaggle/working/data.csv
# is_use_cloudmask.............. False
# cloud_threshold............... 0.2
# is_test....................... False
# optimizer..................... Adam
# lr............................ 0.0001
# lr_step....................... 5
# lr_start_epoch_decay.......... 5
# max_epochs.................... 1
# save_freq..................... 1
# save_model_dir................ /kaggle/working/checkpoints
# resume_checkpoint............. None
# train_from_scratch............ True
# experiment_name............... dual_gpu_training
# notes.........................
# use_ddp....................... False
# local_rank.................... -1
# ============================================================
#
# GPUs available: 2
# Using DataParallel on 2 GPUs
#
# Training samples: 12833
# Validation samples: 2749
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model moved to GPU
# ---------- Networks initialized -------------
# [Network] Total number of parameters : 14.827 M
# -----------------------------------------------
# Model wrapped with DataParallel on 2 GPUs
#
# ============================================================
# Starting Training
# ============================================================
#
#
# ============================================================
# Epoch 0/0
# ============================================================
# Training Epoch 0: 100%|█████| 1605/1605 [56:58<00:00,  2.13s/batch, loss=0.0370]
#
# Running validation...
# Validating: 100%|█| 344/344 [03:40<00:00,  1.56batch/s, PSNR=26.92, SSIM=0.8255]
# ✓ Saved checkpoint: /kaggle/working/checkpoints/checkpoint_epoch_0.pth
#
# ============================================================
# Epoch 0 Summary:
#   Train Loss: 0.0370
#   Train PSNR: 23.47 dB
#   Val PSNR:   26.92 dB
#   Val SSIM:   0.8255
#   Best Val PSNR: 26.92 dB (NEW!)
#   Epoch Time: 60.7 minutes
# ============================================================
#
# ============================================================
# Training Complete!
# ============================================================
# Total Time: 1.01 hours
# Best Validation PSNR: 26.92 dB
# Training log saved to: /kaggle/working/checkpoints/logs/dual_gpu_training_log.json
# Best model saved to: /kaggle/working/checkpoints/best_model.pth
# ============================================================
#
# ✅ All checkpoints copied to: /kaggle/output/checkpoints
# ✅ Training log copied to: /kaggle/output/dual_gpu_training_log.json
#
# ============================================================
# 📥 Download Instructions (Kaggle Notebooks)
# ============================================================
# 1. Click the 'Output' tab in your Kaggle notebook
# 2. You should see:
#    - best_model.pth (best checkpoint)
#    - checkpoints/ (all epoch checkpoints)
#    - dual_gpu_training_log.json (training logs)
# 3. Click the download icon next to each file
#
# 💾 Files are ready to download from Kaggle Output!
# ============================================================
#
# ^C
# Exception ignored in atexit callback: <function _MultiProcessingDataLoaderIter._clean_up_worker at 0x7c439922fce0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1612, in _clean_up_worker
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 948, in wait
#     ready = selector.select(timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:

# %%
# !cd /kaggle/working/checkpoints

# %%
ls
# Out:
# checkpoints/  data.csv  glfCRPLUS/  test.csv  train.csv  val.csv

# %%
# !zip -r checkpoints.zip checkpoints
# Out:
#   adding: checkpoints/ (stored 0%)
#   adding: checkpoints/model_dataset/ (stored 0%)
#   adding: checkpoints/model_dataset/dataset-metadata.json (stored 0%)
#   adding: checkpoints/model_dataset/checkpoint_epoch_0.pth (deflated 14%)
#   adding: checkpoints/checkpoint_epoch_0.pth (deflated 14%)
#   adding: checkpoints/state.db (deflated 87%)
#   adding: checkpoints/logs/ (stored 0%)
#   adding: checkpoints/logs/dual_gpu_training_log.json (deflated 54%)
